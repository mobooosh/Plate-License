# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !python yolov9/detect.py --weights yolov9-e.pt --source car.jpg --device 0
# Out:
# Traceback (most recent call last):
#   File "/home/syydmr/Desktop/Deep Learning/RNN Projects/Plate License Rec/Plate_license/yolov9/detect.py", line 7, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
from IPython.display import Image
Image(filename=f"car.jpg", width=1000)
