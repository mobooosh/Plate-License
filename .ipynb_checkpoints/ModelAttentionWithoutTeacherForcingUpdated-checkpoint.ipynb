# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '15'

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.15.1'

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
device = tf.config.list_physical_devices('GPU')[0]
tf.config.experimental.set_memory_growth(device, True)

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Attention, Lambda, GRU, GlobalAveragePooling1D, Concatenate, Reshape, Conv2D, MaxPooling2D, Dropout, Dense, Flatten, LSTM, Input, BatchNormalization, GlobalAveragePooling2D
from keras.layers import Embedding
import os
from keras import layers

# %%
train_dir = "mergedData"

# %%
path = os.listdir(train_dir)
lbl = []
for e in path:
    lbl.append(e.split('_')[0])

# %%
characters = set(char for label in lbl for char in label)

characters = sorted(list(characters))

char_to_num = layers.StringLookup(
    vocabulary=list(characters), mask_token=None
)
num_to_char = layers.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)

# %%
dict_ = char_to_num.get_vocabulary()

# %%
image_paths = []
tokenized_lbls = []
for i in path:
    image_paths.append(os.path.join(train_dir, i))
    temp = []
    for char in i.split('_')[0]:
        temp.append(int(char_to_num(char)))
    tokenized_lbls.append(temp)

# %%
tf.config.optimizer.set_jit(True)
AUTOTUNE = tf.data.experimental.AUTOTUNE
desired_height = 65
desired_width = 256

def normalization(image):
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image

def load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=1)
    image = normalization(image)    
    image = tf.image.resize(image, [desired_height, desired_width])
    image = tf.transpose(image, perm=[1, 0, 2])
    return image

# def data_augmentation(image):
#     image = tf.image.adjust_contrast(image, 0.4)
#     image = tf.image.adjust_brightness(image, 0.3)
#     image = tf.image.adjust_saturation(image, 0.3)
#     return image


def load_image_label(path, label):
    image = load_image(path)
    # image = data_augmentation(image)
    label = tf.cast(label, tf.float32)
    return image, label
    
SHUFFLE_BUFFER_SIZE = 256
BATCH_SIZE = 32

# %%
dataset = tf.data.Dataset.from_tensor_slices((image_paths, tokenized_lbls))


validation_split = 0.04
DATASET_SIZE = len(list(dataset))
print("Dataset size: ", DATASET_SIZE)
train_size = int((1-validation_split) * DATASET_SIZE)
print("train size: ", train_size)
train_dataset = dataset.take(train_size)
validation_dataset = dataset.skip(train_size)



dataset = dataset.map(load_image_label, num_parallel_calls=AUTOTUNE)
dataset = dataset.shuffle(SHUFFLE_BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, num_parallel_calls=AUTOTUNE)
dataset = dataset.prefetch(AUTOTUNE)



train_dataset = train_dataset.map(load_image_label, num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE, num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.prefetch(AUTOTUNE)

validation_dataset = validation_dataset.map(load_image_label, num_parallel_calls=AUTOTUNE)
validation_dataset = validation_dataset.batch(BATCH_SIZE, num_parallel_calls=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(AUTOTUNE)
# Out:
# Dataset size:  8519
# train size:  8178

# %%
for source, label in train_dataset.take(1):
    source = source[0]
    label = label[0]
    plt.imshow((source))
    print(label)
# Out:
# tf.Tensor([ 3.  3. 26.  5.  6.  2.  2.  6.], shape=(8,), dtype=float32)

# %%
from keras.models import Model
new_shape = (desired_width // 16, (desired_height // 16) * 256)
nclasses = len(char_to_num.get_vocabulary())

# Encoder
input_layer = tf.keras.Input(shape=(desired_width, desired_height, 1))
conv2d1 = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(input_layer)
pool1 = layers.MaxPooling2D((2, 2))(conv2d1)

conv2d2 = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(pool1)
pool2 = layers.MaxPooling2D((2, 2))(conv2d2)

conv2d3 = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(pool2)
pool3 = layers.MaxPooling2D((2, 2))(conv2d3)

conv2d4 = layers.Conv2D(256, (3, 3), activation="relu", padding="same")(pool3)
pool4 = layers.MaxPooling2D((2, 2))(conv2d4)

reshape = layers.Reshape(target_shape=new_shape)(pool4)
dense_1 = layers.Dense(128, activation="relu")(reshape)
dropout1 = layers.Dropout(0.2)(dense_1)
conv1d = layers.Conv1D(64, 3, activation="relu", padding="same")(dropout1)

# %%
# LSTM Layers
lstm1 = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(conv1d)
lstm2 = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(lstm1)

class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        score = self.V(tf.nn.tanh(self.W1(query_with_time_axis) + self.W2(values)))
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

attention = BahdanauAttention(256)
context_vector, attention_weights = attention(lstm2[:, -1, :], lstm2)

context_vector_repeated = tf.keras.layers.RepeatVector(lstm2.shape[1])(context_vector)

combined = tf.keras.layers.Concatenate(axis=-1)([context_vector_repeated, lstm2])




decoder_lstm = layers.Bidirectional(layers.LSTM(64, return_sequences=True))(combined)







output = layers.TimeDistributed(layers.Dense(nclasses, activation='softmax'))(decoder_lstm)




output = layers.MaxPooling1D((2,))(output)





model = Model(inputs=input_layer, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 65, 1)]         0         []
#
#  conv2d_4 (Conv2D)           (None, 256, 65, 32)          320       ['input_2[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 32, 32)          0         ['conv2d_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 128, 32, 64)          18496     ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 16, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 16, 128)          73856     ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 8, 128)           0         ['conv2d_6[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 8, 256)           295168    ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 4, 256)           0         ['conv2d_7[0][0]']
#  g2D)
#
#  reshape_1 (Reshape)         (None, 16, 1024)             0         ['max_pooling2d_7[0][0]']
#
#  dense_5 (Dense)             (None, 16, 128)              131200    ['reshape_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 16, 128)              0         ['dense_5[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 16, 64)               24640     ['dropout_1[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 16, 128)              66048     ['conv1d_1[0][0]']
#  onal)
#
#  bidirectional_4 (Bidirecti  (None, 16, 128)              98816     ['bidirectional_3[0][0]']
#  onal)
#
#  tf.__operators__.getitem_1  (None, 128)                  0         ['bidirectional_4[0][0]']
#   (SlicingOpLambda)
#
#  bahdanau_attention_1 (Bahd  ((None, 128),                66305     ['tf.__operators__.getitem_1[0
#  anauAttention)               (None, 16, 1))                        ][0]',
#                                                                      'bidirectional_4[0][0]']
#
#  repeat_vector_1 (RepeatVec  (None, 16, 128)              0         ['bahdanau_attention_1[0][0]']
#  tor)
#
#  concatenate_1 (Concatenate  (None, 16, 256)              0         ['repeat_vector_1[0][0]',
#  )                                                                   'bidirectional_4[0][0]']
#
#  bidirectional_5 (Bidirecti  (None, 16, 128)              164352    ['concatenate_1[0][0]']
#  onal)
#
#  time_distributed_1 (TimeDi  (None, 16, 29)               3741      ['bidirectional_5[0][0]']
#  stributed)
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 29)                0         ['time_distributed_1[0][0]']
#  g1D)
#
# ==================================================================================================
# Total params: 942942 (3.60 MB)
# Trainable params: 942942 (3.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, show_dtype=True, show_shapes=True, show_layer_names=True)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)


model.compile(
    optimizer=opt,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],

)

# %%
epochs = 100
early_stopping_patience = 15
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.7,
                              patience=3, min_lr=0.0001)

# %%
model.fit(train_dataset, epochs=epochs, validation_data=validation_dataset, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718644142.137625    4035 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718644142.156146    4035 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718644143.400556    4031 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718644143.859140    4037 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718644144.507751    4031 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 256/256 [==============================] - ETA: 0s - loss: 2.3808 - accuracy: 0.1884
# W0000 00:00:1718644175.343814    4030 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1718644175.508476    4030 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 256/256 [==============================] - 47s 84ms/step - loss: 2.3808 - accuracy: 0.1884 - val_loss: 2.1435 - val_accuracy: 0.2148 - lr: 0.0010
# Epoch 2/100
# 256/256 [==============================] - ETA: 0s - loss: 2.0492 - accuracy: 0.2299
# W0000 00:00:1718644200.222734    4037 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 256/256 [==============================] - 27s 106ms/step - loss: 2.0492 - accuracy: 0.2299 - val_loss: 1.7920 - val_accuracy: 0.3383 - lr: 0.0010
# Epoch 3/100
# 256/256 [==============================] - 13s 52ms/step - loss: 1.3866 - accuracy: 0.4848 - val_loss: 1.0027 - val_accuracy: 0.6415 - lr: 0.0010
# Epoch 4/100
# 256/256 [==============================] - 14s 53ms/step - loss: 0.7571 - accuracy: 0.7436 - val_loss: 0.5379 - val_accuracy: 0.8328 - lr: 0.0010
# Epoch 5/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.4567 - accuracy: 0.8632 - val_loss: 0.3289 - val_accuracy: 0.9069 - lr: 0.0010
# Epoch 6/100
# 256/256 [==============================] - 15s 56ms/step - loss: 0.3066 - accuracy: 0.9131 - val_loss: 0.2721 - val_accuracy: 0.9249 - lr: 0.0010
# Epoch 7/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.2216 - accuracy: 0.9405 - val_loss: 0.1810 - val_accuracy: 0.9560 - lr: 0.0010
# Epoch 8/100
# 256/256 [==============================] - 15s 59ms/step - loss: 0.1711 - accuracy: 0.9567 - val_loss: 0.1510 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 9/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.1351 - accuracy: 0.9668 - val_loss: 0.1236 - val_accuracy: 0.9692 - lr: 0.0010
# Epoch 10/100
# 256/256 [==============================] - 14s 56ms/step - loss: 0.1102 - accuracy: 0.9733 - val_loss: 0.1101 - val_accuracy: 0.9721 - lr: 0.0010
# Epoch 11/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0863 - accuracy: 0.9800 - val_loss: 0.1025 - val_accuracy: 0.9743 - lr: 0.0010
# Epoch 12/100
# 256/256 [==============================] - 14s 53ms/step - loss: 0.0714 - accuracy: 0.9838 - val_loss: 0.0924 - val_accuracy: 0.9791 - lr: 0.0010
# Epoch 13/100
# 256/256 [==============================] - 14s 53ms/step - loss: 0.0652 - accuracy: 0.9845 - val_loss: 0.0889 - val_accuracy: 0.9813 - lr: 0.0010
# Epoch 14/100
# 256/256 [==============================] - 18s 68ms/step - loss: 0.0643 - accuracy: 0.9841 - val_loss: 0.0926 - val_accuracy: 0.9802 - lr: 0.0010
# Epoch 15/100
# 256/256 [==============================] - 16s 60ms/step - loss: 0.0513 - accuracy: 0.9878 - val_loss: 0.0838 - val_accuracy: 0.9809 - lr: 0.0010
# Epoch 16/100
# 256/256 [==============================] - 14s 56ms/step - loss: 0.0434 - accuracy: 0.9895 - val_loss: 0.0981 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 17/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0357 - accuracy: 0.9906 - val_loss: 0.0750 - val_accuracy: 0.9853 - lr: 0.0010
# Epoch 18/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0354 - accuracy: 0.9911 - val_loss: 0.0784 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 19/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0353 - accuracy: 0.9906 - val_loss: 0.0763 - val_accuracy: 0.9846 - lr: 0.0010
# Epoch 20/100
# 256/256 [==============================] - 14s 53ms/step - loss: 0.0232 - accuracy: 0.9943 - val_loss: 0.0802 - val_accuracy: 0.9831 - lr: 0.0010
# Epoch 21/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.0195 - accuracy: 0.9955 - val_loss: 0.0821 - val_accuracy: 0.9850 - lr: 7.0000e-04
# Epoch 22/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.0797 - val_accuracy: 0.9839 - lr: 7.0000e-04
# Epoch 23/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.0800 - val_accuracy: 0.9835 - lr: 7.0000e-04
# Epoch 24/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0759 - val_accuracy: 0.9842 - lr: 4.9000e-04
# Epoch 25/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0790 - val_accuracy: 0.9842 - lr: 4.9000e-04
# Epoch 26/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0778 - val_accuracy: 0.9831 - lr: 4.9000e-04
# Epoch 27/100
# 256/256 [==============================] - 14s 56ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0826 - val_accuracy: 0.9850 - lr: 3.4300e-04
# Epoch 28/100
# 256/256 [==============================] - 14s 54ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0775 - val_accuracy: 0.9853 - lr: 3.4300e-04
# Epoch 29/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0755 - val_accuracy: 0.9846 - lr: 3.4300e-04
# Epoch 30/100
# 256/256 [==============================] - 14s 55ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0804 - val_accuracy: 0.9864 - lr: 2.4010e-04
# Epoch 31/100
# 256/256 [==============================] - 14s 56ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0796 - val_accuracy: 0.9835 - lr: 2.4010e-04
# Epoch 32/100
# 256/256 [==============================] - 14s 56ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0776 - val_accuracy: 0.9872 - lr: 2.4010e-04

# %%
# model.save('model_best.keras')
# model.save('model_best.h5')

# %%
import cv2
path = '1K866666_4325035.JPG'
test_image = cv2.imread(path)
test_image = test_image.astype(np.float32) / 255.0
test_image = cv2.resize(test_image, dsize=(256, 65))
test_image = cv2.transpose(test_image)
test_image = cv2.cvtColor(test_image, cv2.COLOR_RGB2GRAY)
resized_image = np.expand_dims(test_image, axis=0)
output = model.predict(resized_image)
output = output.argmax(axis=-1)[0]
tensor_list = [num_to_char(item) for item in output]
string_list = [tensor.numpy().decode('utf-8') for tensor in tensor_list]
resulting_string = ''.join(string_list)
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
resulting_string
# Out:
# '18H67666'
